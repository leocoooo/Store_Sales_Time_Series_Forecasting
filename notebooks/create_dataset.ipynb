# %%
import os 
import pandas as pd
import numpy as np

os.chdir("../")
os.getcwd()
# Out:
# 'c:\\Users\\leoco\\Documents\\cours\\M2_MOSEF\\time_series_deep_learning\\Store_Sales_Time_Series_Forecasting'

# %%
from src.create_dataset import create_dataset, optimize_memory

# %%
main_df = pd.read_csv('data/main_df.csv', parse_dates=['date'])
stores_df = pd.read_csv('data/stores.csv')
oil_df = pd.read_csv('data/oil.csv', parse_dates=['date'])
holidays_df = pd.read_csv('data/holidays_events.csv', parse_dates=['date'])

# %%
main_df.head()
# Out:
#    id       date  store_nbr      family  sales  onpromotion
# 0   0 2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1 2013-01-01          1   BABY CARE    0.0            0
# 2   2 2013-01-01          1      BEAUTY    0.0            0
# 3   3 2013-01-01          1   BEVERAGES    0.0            0
# 4   4 2013-01-01          1       BOOKS    0.0            0

# %%
stores_df.head()
# Out:
#    store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4

# %%
oil_df.head()
# Out:
#         date  dcoilwtico
# 0 2013-01-01         NaN
# 1 2013-01-02       93.14
# 2 2013-01-03       92.97
# 3 2013-01-04       93.12
# 4 2013-01-07       93.20

# %%
holidays_df.head()
# Out:
#         date     type    locale locale_name                    description  \
# 0 2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1 2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2 2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3 2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4 2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
sales_df = create_dataset(main_df, stores_df, oil_df, holidays_df)

# %%
sales_df = optimize_memory(sales_df)
# Out:
# Mémoire initiale: 1087.51 MB
# Mémoire finale: 417.84 MB
# Réduction de: 61.6%

# %%
sales_df.head()
# Out:
#         id       date  store_nbr      family  sales  onpromotion   city  \
# 0        0 2013-01-01          1  AUTOMOTIVE    0.0            0  Quito
# 1782  1782 2013-01-02          1  AUTOMOTIVE    2.0            0  Quito
# 3564  3564 2013-01-03          1  AUTOMOTIVE    3.0            0  Quito
# 5346  5346 2013-01-04          1  AUTOMOTIVE    3.0            0  Quito
# 7128  7128 2013-01-05          1  AUTOMOTIVE    5.0            0  Quito
#
#           state store_type  cluster  ...  sales_lag_56 sales_lag_364  \
# 0     Pichincha          D       13  ...           NaN           NaN
# 1782  Pichincha          D       13  ...           NaN           NaN
# 3564  Pichincha          D       13  ...           NaN           NaN
# 5346  Pichincha          D       13  ...           NaN           NaN
# 7128  Pichincha          D       13  ...           NaN           NaN
#
#       rolling_mean_7  rolling_mean_28  rolling_std_7  store_family_velocity  \
# 0                NaN              NaN            NaN                    NaN
# 1782             NaN              NaN            NaN               0.000000
# 3564             NaN              NaN            NaN               1.000000
# 5346             NaN              NaN            NaN               1.666667
# 7128             NaN              NaN            NaN               2.000000
#
#       target_enc_store_family  oil_trend_30  promo_ratio_vs_avg  \
# 0                    0.000000          0.00                 0.0
# 1782                 0.000000          0.00                 0.0
# 3564                 1.000000         -0.17                 0.0
# 5346                 1.666667         -0.02                 0.0
# 7128                 2.000000         -0.02                 0.0
#
#       promo_during_payday
# 0                       0
# 1782                    0
# 3564                    0
# 5346                    0
# 7128                    0
#
# [5 rows x 48 columns]

# %%
sales_df.isnull().sum()
# Out:
# id                              0
# date                            0
# store_nbr                       0
# family                          0
# sales                           0
# onpromotion                     0
# city                            0
# state                           0
# store_type                      0
# cluster                         0
# dcoilwtico                      0
# holiday_type                    0
# is_holiday_local                0
# is_holiday_regional             0
# is_holiday_national             0
# is_store_closed                 0
# day_of_week                     0
# month                           0
# year                            0
# time_idx                        0
# is_weekend                      0
# is_payday                       0
# month_sin                       0
# month_cos                       0
# day_sin                         0
# day_cos                         0
# is_earthquake_impact            0
# days_to_christmas               0
# sales_lag_1                  1782
# sales_lag_2                  3564
# sales_lag_3                  5346
# sales_lag_4                  7128
# sales_lag_5                  8910
# sales_lag_6                 10692
# sales_lag_7                 12474
# sales_lag_14                24948
# sales_lag_21                37422
# sales_lag_28                49896
# sales_lag_56                99792
# sales_lag_364              648648
# rolling_mean_7              12474
# rolling_mean_28             49896
# rolling_std_7               12474
# store_family_velocity           1
# target_enc_store_family         0
# oil_trend_30                    0
# promo_ratio_vs_avg              0
# promo_during_payday             0
# dtype: int64
